# %% [markdown]
# ## Manipulação dos Dados retirados do QGIS

# %%
import pandas as pd

XINGU = pd.read_csv('Bacias_2008/XINGU.csv')
URUGUAI = pd.read_csv('Bacias_2008/URUGUAI.csv')
UATUAMA = pd.read_csv('Bacias_2008/UATUAMA.csv')
TIETE = pd.read_csv('Bacias_2008/TIETE.csv')
TOCANTINS = pd.read_csv('Bacias_2008/TOCANTINS.csv')
TAPAJOS = pd.read_csv('Bacias_2008/TAPAJOS.csv')
SAO_FRANCISCO = pd.read_csv('Bacias_2008/SAO_FRANCISCO.csv')
PARNAIBA = pd.read_csv('Bacias_2008/PARNAIBA.csv')
PARANAPANEMA = pd.read_csv('Bacias_2008/PARANAPANEMA.csv')
PARANAIBA = pd.read_csv('Bacias_2008/PARANAIBA.csv')
PARANA = pd.read_csv('Bacias_2008/PARANA.csv')
PARAIBA_DO_SUL = pd.read_csv('Bacias_2008/PARAIBA_DO_SUL.csv')
PARAGUACU = pd.read_csv('Bacias_2008/PARAGUACU.csv')
MUCURI = pd.read_csv('Bacias_2008/MUCURI.csv')
MANSO = pd.read_csv('Bacias_2008/MANSO.csv')
MADEIRA = pd.read_csv('Bacias_2008/MADEIRA.csv')
JEQUITINHONHA = pd.read_csv('Bacias_2008/JEQUITINHONHA.csv')
JAURU = pd.read_csv('Bacias_2008/JAURU.csv')
JARI = pd.read_csv('Bacias_2008/JARI.csv')
JACUI = pd.read_csv('Bacias_2008/JACUI.csv')
ITIQUIRA = pd.read_csv('Bacias_2008/ITIQUIRA.csv')
ITAJAI_ACU = pd.read_csv('Bacias_2008/ITAJAI_ACU.csv')
ITABAPOANA = pd.read_csv('Bacias_2008/ITABAPOANA.csv')
IGUACU = pd.read_csv('Bacias_2008/IGUACU.csv')
GRANDE = pd.read_csv('Bacias_2008/GRANDE.csv')
DOCE = pd.read_csv('Bacias_2008/DOCE.csv')
CURRUA_UNA = pd.read_csv('Bacias_2008/CURRUA_UNA.csv')
CORRENTES = pd.read_csv('Bacias_2008/CORRENTES.csv')
CAPIVARI = pd.read_csv('Bacias_2008/CAPIVARI.csv')
ARAGUARI = pd.read_csv('Bacias_2008/ARAGUARI.csv')
ANTAS = pd.read_csv('Bacias_2008/ANTAS.csv')

# %%
ANTAS['nome'] = 'Antas'
ANTAS['ano'] = 2008

ARAGUARI['nome'] = 'Araguari'
ARAGUARI['ano'] = 2008

CAPIVARI['nome'] = 'Capivari'
CAPIVARI['ano'] = 2008

CORRENTES['nome'] = 'Correntes'
CORRENTES['ano'] = 2008

CURRUA_UNA['nome'] = 'Curruá Una'
CURRUA_UNA['ano'] = 2008

DOCE['nome'] = 'Doce'
DOCE['ano'] = 2008

GRANDE['nome'] = 'Grande'
GRANDE['ano'] = 2008

IGUACU['nome'] = 'Iguaçu'
IGUACU['ano'] = 2008

ITABAPOANA['nome'] = 'Itabapoana'
ITABAPOANA['ano'] = 2008

ITAJAI_ACU['nome'] = 'Itajaí-Açú'
ITAJAI_ACU['ano'] = 2008

ITIQUIRA['nome'] = 'Itiquira'
ITIQUIRA['ano'] = 2008

JACUI['nome'] = 'Jacuí'
JACUI['ano'] = 2008

JARI['nome'] = 'Jari'
JARI['ano'] = 2008

JAURU['nome'] = 'Jauru'
JAURU['ano'] = 2008

JEQUITINHONHA['nome'] = 'Jequitinhonha'
JEQUITINHONHA['ano'] = 2008

MANSO['nome'] = 'Manso'
MANSO['ano'] = 2008

MADEIRA['nome'] = 'Madeira'
MADEIRA['ano'] = 2008

MUCURI['nome'] = 'Mucuri'
MUCURI['ano'] = 2008

PARAGUACU['nome'] = 'Paraguaçu'
PARAGUACU['ano'] = 2008

PARAIBA_DO_SUL['nome'] = 'Paraíba do Sul'
PARAIBA_DO_SUL['ano'] = 2008

PARANA['nome'] = 'Paraná'
PARANA['ano'] = 2008

PARANAIBA['nome'] = 'Paranaíba'
PARANAIBA['ano'] = 2008

PARANAPANEMA['nome'] = 'Paranapanema'
PARANAPANEMA['ano'] = 2008

PARNAIBA['nome'] = 'Parnaíba'
PARNAIBA['ano'] = 2008

SAO_FRANCISCO['nome'] = 'São Francisco'
SAO_FRANCISCO['ano'] = 2008

TAPAJOS['nome'] = 'Tapajós'
TAPAJOS['ano'] = 2008

TIETE['nome'] = 'Tietê'
TIETE['ano'] = 2008

TOCANTINS['nome'] = 'Tocantins'
TOCANTINS['ano'] = 2008

UATUAMA['nome'] = 'Uatuamã'
UATUAMA['ano'] = 2008

URUGUAI['nome'] = 'Uruguai'
URUGUAI['ano'] = 2008

XINGU['nome'] = 'Xingú'
XINGU['ano'] = 2008

# %% [markdown]
# ## Salvando Dados Manipulados

# %%
XINGU.to_csv('Bacias_2008/XINGU.csv')
URUGUAI.to_csv('Bacias_2008/URUGUAI.csv')
UATUAMA.to_csv('Bacias_2008/UATUAMA.csv')
TIETE.to_csv('Bacias_2008/TIETE.csv')
TOCANTINS.to_csv('Bacias_2008/TOCANTINS.csv')
TAPAJOS.to_csv('Bacias_2008/TAPAJOS.csv')
SAO_FRANCISCO.to_csv('Bacias_2008/SAO_FRANCISCO.csv')
PARNAIBA.to_csv('Bacias_2008/PARNAIBA.csv')
PARANAPANEMA.to_csv('Bacias_2008/PARANAPANEMA.csv')
PARANAIBA.to_csv('Bacias_2008/PARANAIBA.csv')
PARANA.to_csv('Bacias_2008/PARANA.csv')
PARAIBA_DO_SUL.to_csv('Bacias_2008/PARAIBA_DO_SUL.csv')
PARAGUACU.to_csv('Bacias_2008/PARAGUACU.csv')
MUCURI.to_csv('Bacias_2008/MUCURI.csv')
MANSO.to_csv('Bacias_2008/MANSO.csv')
MADEIRA.to_csv('Bacias_2008/MADEIRA.csv')
JEQUITINHONHA.to_csv('Bacias_2008/JEQUITINHONHA.csv')
JAURU.to_csv('Bacias_2008/JAURU.csv')
JACUI.to_csv('Bacias_2008/JACUI.csv')
JARI.to_csv('Bacias_2008/JARI.csv')
ITIQUIRA.to_csv('Bacias_2008/ITIQUIRA.csv')
ITAJAI_ACU.to_csv('Bacias_2008/ITAJAI_ACU.csv')
ITABAPOANA.to_csv('Bacias_2008/ITABAPOANA.csv')
IGUACU.to_csv('Bacias_2008/IGUACU.csv')
GRANDE.to_csv('Bacias_2008/GRANDE.csv')
DOCE.to_csv('Bacias_2008/DOCE.csv')
CURRUA_UNA.to_csv('Bacias_2008/CURRUA_UNA.csv')
CORRENTES.to_csv('Bacias_2008/CORRENTES.csv')
CAPIVARI.to_csv('Bacias_2008/CAPIVARI.csv')
ARAGUARI.to_csv('Bacias_2008/ARAGUARI.csv')
ANTAS.to_csv('Bacias_2008/ANTAS.csv')

# %%
UNIDO_21 = pd.read_csv('UNIDO_21.csv')

# %%
dfs = [XINGU, URUGUAI, UATUAMA, TIETE, TOCANTINS, TAPAJOS, SAO_FRANCISCO, PARNAIBA, PARANAPANEMA, PARANAIBA, PARANA, PARAIBA_DO_SUL, PARAGUACU, MUCURI, MADEIRA, MANSO, JEQUITINHONHA, JAURU, JARI, JACUI, ITIQUIRA, ITAJAI_ACU, ITABAPOANA, IGUACU, GRANDE, DOCE, CURRUA_UNA, CORRENTES, CAPIVARI, ARAGUARI, ANTAS, UNIDO_21]
UNIDO = pd.concat(dfs, ignore_index=True)
UNIDO = UNIDO.groupby(['DN', 'nome', 'ano']).agg({'area': 'sum'}).reset_index()

# %%
UNIDO.to_csv('UNIDO.csv')
